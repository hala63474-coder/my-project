# %% [markdown]
# <a href="https://colab.research.google.com/github/hala63474-coder/my-project/blob/main/untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import tensorflow as tf

# %%
fake_videos_path = '/content/drive/MyDrive/dataset/fake'
real_videos_path = '/content/drive/MyDrive/dataset/real'
output_path = '/content/drive/MyDrive/frames'

fake_folder = os.path.join(output_path, 'fake')
real_folder = os.path.join(output_path, 'real')

os.makedirs(fake_folder, exist_ok=True)
os.makedirs(real_folder, exist_ok=True)

# %%
def extract_frames(video_path, save_folder, label, max_frames=50):
    """
    video_path: مسار الفيديو
    save_folder: مجلد الحفظ
    label: 'fake' أو 'real'
    max_frames: عدد أقصى للفريمات من كل فيديو
    """
    cap = cv2.VideoCapture(video_path)
    count = 0

    while cap.isOpened() and count < max_frames:
        ret, frame = cap.read()
        if not ret:
            break

        filename = f"{label}_{os.path.basename(video_path)}_{count}.jpg"
        filepath = os.path.join(save_folder, filename)

        if not os.path.exists(filepath):  # لو الصورة موجودة مسبقاً لا ننسخ
            cv2.imwrite(filepath, frame)
        count += 1

    cap.release()

# %%
import os

if not os.path.exists(output_path) or len(os.listdir(output_path)) == 0:

    print("Extracting frames...")

    # Fake videos
    for video in os.listdir(fake_videos_path)[:100]:
        extract_frames(os.path.join(fake_videos_path, video), fake_folder, 'fake')

    # Real videos
    for video in os.listdir(real_videos_path)[:100]:
        extract_frames(os.path.join(real_videos_path, video), real_folder, 'real')

    print("Finished extracting frames")

else:
    print("Frames already exist, skipping extraction")
# Out:
# Frames already exist, skipping extraction

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

batch_size = 32
img_height = 224
img_width = 224

train_data = datagen.flow_from_directory(
    output_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='training'
)

val_data = datagen.flow_from_directory(
    output_path,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='binary',
    subset='validation'
)

print("✅ Data ready for training")
# Out:
# Found 6217 images belonging to 2 classes.
# Found 1554 images belonging to 2 classes.
# ✅ Data ready for training

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout,GlobalAveragePooling2D

model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),

    GlobalAveragePooling2D(),

    Dense(128, activation='relu'),
    Dropout(0.5),

    Dense(1, activation='sigmoid')  # binary: fake / real
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,889 (429.25 KB)
#  Trainable params: 109,889 (429.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.models import load_model

model_path = '/content/drive/MyDrive/deepfake_model.h5'

#model = load_model(model_path, compile=False)

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

print("🔥 الموديل جاهز")
# Out:
# 🔥 الموديل جاهز

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True
)

history = model.fit(
    train_data,
    validation_data=val_data,
    epochs=5,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/5
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 130s 668ms/step - accuracy: 0.6090 - loss: 0.6454 - val_accuracy: 0.5882 - val_loss: 0.7446
# Epoch 2/5
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 128s 658ms/step - accuracy: 0.6637 - loss: 0.5815 - val_accuracy: 0.6461 - val_loss: 0.6027
# Epoch 3/5
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 128s 656ms/step - accuracy: 0.7317 - loss: 0.4813 - val_accuracy: 0.7806 - val_loss: 0.5990
# Epoch 4/5
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 128s 656ms/step - accuracy: 0.7549 - loss: 0.4255 - val_accuracy: 0.7484 - val_loss: 0.6519
# Epoch 5/5
# 195/195 ━━━━━━━━━━━━━━━━━━━━ 125s 642ms/step - accuracy: 0.7817 - loss: 0.3967 - val_accuracy: 0.7748 - val_loss: 0.6335

# %%
loss, acc = model.evaluate(val_data)
print(f"Model Accuracy:{acc*100:.2f}%")
# Out:
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 24s 494ms/step - accuracy: 0.7806 - loss: 0.5990
# Model Accuracy:78.06%

# %%
model.save('/content/drive/MyDrive/deepfake_model.keras')
print("✅ Model saved!")
# Out:
# ✅ Model saved!

# %%
import os

print(os.listdir('/content/drive/MyDrive/frames/real')[:5])
# Out:
# ['real_01__kitchen_still.mp4_0.jpg', 'real_01__kitchen_still.mp4_1.jpg', 'real_01__kitchen_still.mp4_2.jpg', 'real_01__kitchen_still.mp4_3.jpg', 'real_01__kitchen_still.mp4_4.jpg']

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# 📌 مسار الصورة
img_path = '/content/drive/MyDrive/frames/real/real_10__walking_down_street_outside_angry.mp4_1.jpg'

# 📌 تحميل الصورة
img = image.load_img(img_path, target_size=(224,224))

# 📌 تحويلها لـ array
img_array = image.img_to_array(img)

# 📌 تجهيزها للموديل
img_array = np.expand_dims(img_array, axis=0) / 255.0

# 📌 التوقع
prediction = model.predict(img_array)

# 📌 النتيجة + النسبة
confidence = prediction[0][0]

if confidence > 0.5:
    print(f"Real ✅ بنسبة {confidence*100:.2f}%")
else:
    print(f"Fake ❌ بنسبة {(1-confidence)*100:.2f}%")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Real ✅ بنسبة 95.16%
